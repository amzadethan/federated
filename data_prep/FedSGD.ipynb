# %%
from ipynb.fs.full.FLDataset import load_dataset, getActualImages

# %%
train_dataset, test_dataset, train_group, test_group = load_dataset(10)

# %%
# lets print train_dataset, train_group, test_dataset & test_group for double checking if everything is fine
print('Train dataset :')
print(train_dataset)

print('Train Group :')
print(train_group)

print("Test dataset :")
print(test_dataset)

print("Test Group :")
print(test_group)
# Out:
# Train dataset :
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#            )
# Train Group :
# ...

# %%
# now we need to call getActualImages

first_client_batches = getActualImages(train_dataset, train_group[0], 64) # train_group[0] is for the first client, 64 is the batch size number

# %%
# to print how many images are on the just first batch 
# for the first client batches we created previously

for images, labels in first_client_batches:
    print(len(images))
    break
# Out:
# 64
# F:\Ethan\federated-learning-tutorial\data_prep\FLDataset.ipynb:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   "cell_type": "code",
